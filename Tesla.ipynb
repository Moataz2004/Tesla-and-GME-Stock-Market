# %%
# !pip install yfinance
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: yfinance in c:\users\pk\anaconda3\lib\site-packages (0.2.43)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\pk\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\pk\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\pk\anaconda3\lib\site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\pk\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\pk\anaconda3\lib\site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\pk\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\pk\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\pk\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\pk\anaconda3\lib\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\pk\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\pk\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pk\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\pk\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\pk\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pk\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pk\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pk\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pk\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pk\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pk\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.7.4)
# Requirement already satisfied: pandas in c:\users\pk\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\pk\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pk\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pk\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pk\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pk\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\pk\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pk\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pk\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pk\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pk\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\pk\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pk\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\pk\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pk\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pk\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\pk\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import yfinance 
import pandas as pd
import matplotlib.pyplot as plt

# %%
tesla = yfinance.Ticker("TSLA")

# %%
tesla_data = tesla.history(period="max")

# %%
tesla_data.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
tesla_revenue = tesla.history(period="max")

# %%
tesla_revenue.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-09-19 00:00:00-04:00  234.000000  244.240005  232.130005  243.919998
# 2024-09-20 00:00:00-04:00  241.520004  243.990005  235.919998  238.250000
# 2024-09-23 00:00:00-04:00  242.610001  250.000000  241.919998  250.000000
# 2024-09-24 00:00:00-04:00  254.080002  257.190002  249.050003  254.270004
# 2024-09-25 00:00:00-04:00  252.539993  256.419891  252.279999  256.140015
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-09-19 00:00:00-04:00  102694600        0.0           0.0
# 2024-09-20 00:00:00-04:00   99879100        0.0           0.0
# 2024-09-23 00:00:00-04:00   86927200        0.0           0.0
# 2024-09-24 00:00:00-04:00   88305900        0.0           0.0
# 2024-09-25 00:00:00-04:00   16159797        0.0           0.0

# %%
gme = yf.Ticker("GME")

# %%
gme_data = gme.history(period="max")

# %%
gme_data.head()
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 2002-02-13 00:00:00-05:00  1.620128  1.693350  1.603296  1.691666  76216000
# 2002-02-14 00:00:00-05:00  1.712707  1.716073  1.670626  1.683250  11021600
# 2002-02-15 00:00:00-05:00  1.683250  1.687458  1.658001  1.674834   8389600
# 2002-02-19 00:00:00-05:00  1.666418  1.666418  1.578047  1.607504   7410400
# 2002-02-20 00:00:00-05:00  1.615921  1.662210  1.603296  1.662210   6892800
#
#                            Dividends  Stock Splits
# Date
# 2002-02-13 00:00:00-05:00        0.0           0.0
# 2002-02-14 00:00:00-05:00        0.0           0.0
# 2002-02-15 00:00:00-05:00        0.0           0.0
# 2002-02-19 00:00:00-05:00        0.0           0.0
# 2002-02-20 00:00:00-05:00        0.0           0.0

# %%
gme_revenue = gme.history(period="max")

# %%
gme_revenue.tail()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2024-09-19 00:00:00-04:00  19.889999  20.030001  19.469999  19.510000
# 2024-09-20 00:00:00-04:00  19.629999  22.030001  19.480000  21.850000
# 2024-09-23 00:00:00-04:00  21.540001  22.559999  21.230000  22.309999
# 2024-09-24 00:00:00-04:00  22.610001  22.719999  21.540001  22.629999
# 2024-09-25 00:00:00-04:00  22.160000  22.830000  22.219999  22.818501
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-09-19 00:00:00-04:00   8902600        0.0           0.0
# 2024-09-20 00:00:00-04:00  61919200        0.0           0.0
# 2024-09-23 00:00:00-04:00  13969500        0.0           0.0
# 2024-09-24 00:00:00-04:00  12057000        0.0           0.0
# 2024-09-25 00:00:00-04:00   1204134        0.0           0.0

# %%
def make_graph(data, title):
    plt.figure(figsize=(10, 5))
    plt.plot(data.index, data['Close'], label='Closing Price', color='blue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Stock Price (USD)')
    plt.legend()
    plt.grid()
    plt.xticks(rotation=45)  
    plt.tight_layout()  
    plt.show()

# %%
make_graph(tesla_data, 'Tesla Stock Price')

# %%
make_graph(gme_data, 'GME Stock Price')
